# %%
import pickle
from PIL import Image
import matplotlib.pyplot as plt

# %%
def load_results(path, env='CartPole-v1', show_frame=False):
    # Read pkl file
    with open(path, 'rb') as file:
        data = pickle.load(file)

    # Assuming the pkl file has a key "images" which is a list of image file paths
    images = data["rendered_images"]
    rewards = data["rewards"]
    vlm_rewards = data["vlm_rewards"]
    var_values = data["vars"]

    print('# of samples: ', len(images))
    vars_dict = {'CartPole-v1': 'pole angle', 'Pendulum-v1': 'pendulum angle', 'MountainCar-v0': 'car position'}
    x_label = vars_dict[env]
    plt.title(path.split('_')[0])
    plt.xlabel(x_label)
    plt.ylabel('VLM reward')
    plt.plot(var_values, vlm_rewards)
    plt.show()

    if show_frame:
        # Load and plot each image
        for img, r, vr, v in zip(images, rewards, vlm_rewards, var_values):
            print(f'var value: {v}, vlm reward: {vr}')
            plt.imshow(img)
            plt.show()

# %%
load_results('CartPole-v1_results.pkl', 'CartPole-v1', show_frame=False)
# Out:
# # of samples:  50

# %%
load_results('CartPole-v1_ViT-B-32_alpha0.0_results.pkl', 'CartPole-v1', show_frame=False)
# Out:
# # of samples:  100

# %%
load_results('CartPole-v1_ViT-L-14_alpha0.0_results.pkl', 'CartPole-v1', show_frame=False)
# Out:
# # of samples:  100

# %%
load_results('CartPole-v1_ViT-L-14_alpha1.0_results.pkl', 'CartPole-v1', show_frame=False)
# Out:
# # of samples:  100

# %%
load_results('CartPole-v1_ViT-bigG-14_alpha0.0_results.pkl', 'CartPole-v1', show_frame=False)
# Out:
# # of samples:  50

# %%
load_results('MountainCar-v0_ViT-L-14_alpha1.0_results.pkl', 'MountainCar-v0', show_frame=False)
# Out:
# # of samples:  100

# %%
load_results('MountainCar-v0_ViT-L-14_alpha0_results.pkl',  'MountainCar-v0', show_frame=False)
# Out:
# # of samples:  100

# %%
load_results('MountainCar-v0_ViT-B-32_alpha0_results.pkl',  'MountainCar-v0', show_frame=False)
# Out:
# # of samples:  100

# %%
load_results('MountainCar-v0_ViT-B-32_alpha1_results.pkl', 'MountainCar-v0',  show_frame=False)
# Out:
# # of samples:  100

# %%
load_results('MountainCar-v0_ViT-bigG-14_alpha0_results.pkl', 'MountainCar-v0',  show_frame=False)
# Out:
# # of samples:  50

# %% [markdown]
# use target description from LLava1.5:
# CLIP-ViT-L-336px
#
# The image is a white background with a curved line drawn on it. The line is shaped like a wave, and it appears to be a graph or a representation of a curve. There is a small car or truck at the end of the curve, giving the impression that it is traveling along the curved path.

# %%
# empty target prompt
load_results('new_prompt/MountainCar-v0_ViT-L-14_alpha1.0_results.pkl', 'MountainCar-v0',  show_frame=False)
# Out:
# # of samples:  50

# %%
# The image is a white background with a curved line drawn on it. The line is shaped like a wave, and it appears to be a graph or a representation of a curve. There is a small car or truck at the end of the curve, giving the impression that it is traveling along the curved path.
load_results('new_prompt/MountainCar-v0_ViT-L-14_alpha1.0_results.pkl', 'MountainCar-v0',  show_frame=False)
# laion
# Out:
# # of samples:  50

# %%
# The image is a white background with a curved line drawn on it. The line is shaped like a wave, and it appears to be a graph or a representation of a curve. There is a small car or truck at the end of the curve, giving the impression that it is traveling along the curved path.
load_results('new_prompt/MountainCar-v0_ViT-L-14_alpha1.0_results.pkl', 'MountainCar-v0',  show_frame=False)
# openai
# Out:
# # of samples:  50

# %%
# The image is a white background with a curved line drawn on it. The line is shaped like a wave, and it appears to be a graph or a representation of a curve. There is a small car or truck at the end of the curve, giving the impression that it is traveling along the curved path.
load_results('new_prompt/MountainCar-v0_ViT-L-14-336_alpha1.0_results.pkl', 'MountainCar-v0',  show_frame=False)
# Out:
# # of samples:  50

# %%
# lower is better
load_results('new_prompt/MountainCar-v0_ViT-L-14_alpha1.0_results.pkl', 'MountainCar-v0',  show_frame=False)
# description too vague
# Out:
# # of samples:  50

# %%
# lower position of the car is better
load_results('new_prompt/MountainCar-v0_ViT-L-14_alpha1.0_results.pkl', 'MountainCar-v0',  show_frame=False)
# Out:
# # of samples:  50

# %%
# the car stays at the lowest position on the curve
load_results('new_prompt/MountainCar-v0_ViT-L-14_alpha1.0_results.pkl', 'MountainCar-v0',  show_frame=False)
# Out:
# # of samples:  50

# %%
# both baesline and target from llava:
# baseline: The image features a graph with a curve that has a small black dot on it. The curve is steep, and the dot is located near the bottom of the curve. The graph is displayed on a white background, making the curve and the dot stand out prominently.
# target: The image is a white background with a curved line drawn on it. The line is shaped like a wave, and it appears to be a graph or a representation of a curve. There is a small car or truck at the end of the curve, giving the impression that it is traveling along the curved path.
load_results('new_prompt/MountainCar-v0_ViT-L-14_alpha1.0_results.pkl', 'MountainCar-v0',  show_frame=False)
# the two sentences are too similar
# Out:
# # of samples:  50

# %%
# use different VLM-RM model from llava
load_results('new_prompt/MountainCar-v0_ViT-B-32_alpha1.0_results.pkl', 'MountainCar-v0',  show_frame=False)
# Out:
# # of samples:  50

# %%
# use different VLM-RM model from llava
load_results('new_prompt/MountainCar-v0_ViT-H-14_alpha1.0_results.pkl', 'MountainCar-v0',  show_frame=True)
# Out:
# # of samples:  50
# var value: -1.2, vlm reward: 0.5939234495162964
# var value: -1.163265306122449, vlm reward: 0.5939234495162964
# var value: -1.126530612244898, vlm reward: 0.5939234495162964
# var value: -1.089795918367347, vlm reward: 0.5939234495162964
# var value: -1.0530612244897959, vlm reward: 0.5939234495162964
# var value: -1.0163265306122449, vlm reward: 0.5939234495162964
# var value: -0.9795918367346939, vlm reward: 0.602850079536438
# var value: -0.9428571428571428, vlm reward: 0.602484941482544
# var value: -0.9061224489795918, vlm reward: 0.5903483033180237
# var value: -0.8693877551020408, vlm reward: 0.5838015675544739
# var value: -0.8326530612244898, vlm reward: 0.5812116861343384
# var value: -0.7959183673469388, vlm reward: 0.5760787725448608
# var value: -0.7591836734693878, vlm reward: 0.5741679668426514
# var value: -0.7224489795918367, vlm reward: 0.5704187154769897
# var value: -0.6857142857142857, vlm reward: 0.5719642639160156
# ...
