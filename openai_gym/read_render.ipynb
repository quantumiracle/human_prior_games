# %%
import pickle
from PIL import Image
import matplotlib.pyplot as plt

# %%
env = ['CartPole-v1', 'Pendulum-v1', 'MountainCar-v0'][2]
# Read pkl file
with open(f'{env}_results.pkl', 'rb') as file:
    data = pickle.load(file)

# Assuming the pkl file has a key "images" which is a list of image file paths
images = data["rendered_images"]
rewards = data["rewards"]
vlm_rewards = data["vlm_rewards"]
var_values = data["vars"]

print('# of samples: ', len(images))
plt.plot(var_values, vlm_rewards)
plt.show()
# Load and plot each image
for img, r, vr, v in zip(images, rewards, vlm_rewards, var_values):
    print(f'var value: {v}, vlm reward: {vr}')
    plt.imshow(img)
    plt.show()
# Out:
# # of samples:  50
# var value: -1.2, vlm reward: 0.4875383973121643
# var value: -1.163265306122449, vlm reward: 0.4875383973121643
# var value: -1.126530612244898, vlm reward: 0.4875383973121643
# var value: -1.089795918367347, vlm reward: 0.4875383973121643
# var value: -1.0530612244897959, vlm reward: 0.4875383973121643
# var value: -1.0163265306122449, vlm reward: 0.4875383973121643
# var value: -0.9795918367346939, vlm reward: 0.48722195625305176
# var value: -0.9428571428571428, vlm reward: 0.4937877655029297
# var value: -0.9061224489795918, vlm reward: 0.4980105757713318
# var value: -0.8693877551020408, vlm reward: 0.4970371127128601
# var value: -0.8326530612244898, vlm reward: 0.4948573708534241
# var value: -0.7959183673469388, vlm reward: 0.4996013045310974
# var value: -0.7591836734693878, vlm reward: 0.495938777923584
# var value: -0.7224489795918367, vlm reward: 0.4962940812110901
# var value: -0.6857142857142857, vlm reward: 0.49217021465301514
# var value: -0.6489795918367347, vlm reward: 0.49608612060546875
# var value: -0.6122448979591837, vlm reward: 0.4940987825393677
# var value: -0.5755102040816327, vlm reward: 0.4867708086967468
# var value: -0.5387755102040817, vlm reward: 0.491011381149292
# var value: -0.5020408163265306, vlm reward: 0.4915148615837097
# var value: -0.4653061224489796, vlm reward: 0.49359214305877686
# var value: -0.4285714285714286, vlm reward: 0.49675798416137695
# var value: -0.3918367346938776, vlm reward: 0.4954622983932495
# var value: -0.35510204081632657, vlm reward: 0.4959191679954529
# var value: -0.31836734693877555, vlm reward: 0.4936559796333313
# var value: -0.28163265306122454, vlm reward: 0.498793363571167
# var value: -0.24489795918367352, vlm reward: 0.4983866214752197
# var value: -0.2081632653061225, vlm reward: 0.49940985441207886
# var value: -0.17142857142857149, vlm reward: 0.5022028684616089
# var value: -0.13469387755102047, vlm reward: 0.4998588562011719
# var value: -0.09795918367346945, vlm reward: 0.4997550845146179
# var value: -0.061224489795918435, vlm reward: 0.504885196685791
# var value: -0.02448979591836742, vlm reward: 0.5019232034683228
# var value: 0.012244897959183598, vlm reward: 0.5030158758163452
# var value: 0.048979591836734615, vlm reward: 0.4975994825363159
# var value: 0.08571428571428563, vlm reward: 0.5010492205619812
# var value: 0.12244897959183665, vlm reward: 0.5102230310440063
# var value: 0.15918367346938767, vlm reward: 0.5031033754348755
# var value: 0.19591836734693868, vlm reward: 0.5041231513023376
# var value: 0.2326530612244897, vlm reward: 0.5003517270088196
# var value: 0.2693877551020407, vlm reward: 0.498859703540802
# var value: 0.30612244897959173, vlm reward: 0.49787116050720215
# var value: 0.34285714285714275, vlm reward: 0.49492090940475464
# var value: 0.37959183673469377, vlm reward: 0.48755520582199097
# var value: 0.4163265306122448, vlm reward: 0.4875383973121643
# var value: 0.4530612244897958, vlm reward: 0.4875383973121643
# var value: 0.4897959183673468, vlm reward: 0.4875383973121643
# var value: 0.5265306122448978, vlm reward: 0.4875383973121643
# var value: 0.5632653061224488, vlm reward: 0.4875383973121643
# var value: 0.6, vlm reward: 0.4875383973121643

# %%
env = 'MountainCar-v0'
# Read pkl file
with open(f'{env}_results.pkl', 'rb') as file:
    data = pickle.load(file)

# Assuming the pkl file has a key "images" which is a list of image file paths
images = data["rendered_images"]
rewards = data["rewards"]
vlm_rewards = data["vlm_rewards"]

print('# of samples: ', len(images))
# Load and plot each image
for img, r, vr in zip(images, rewards, vlm_rewards):
    print('vlm reward: ', vr)
    plt.imshow(img)
    plt.show()
